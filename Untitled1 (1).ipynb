# %%
import os
import pandas as pd
import numpy as np
import cv2
from tqdm import tqdm

# Function to preprocess the images
def preprocess_images(csv_file, img_dir, output_dir):
    # Read the CSV file
    df = pd.read_csv(csv_file)

    # Loop through each row in the CSV file
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # Get the image file name and label
        img_file = row['id_code']
        label = None
        if 'diagnosis' in row:
            label = row['diagnosis']
        # Load the image and resize
        img_path = os.path.join(img_dir, f"{img_file}.png")
        try:
            img = cv2.imread(img_path)
            if img is None:
                raise ValueError(f"Failed to load image at path {img_path}")
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (512, 512))
        except Exception as e:
            print(f"Error preprocessing image {img_path}: {e}")
            continue

        # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
        img_lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        img_l, img_a, img_b = cv2.split(img_lab)
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        img_l = clahe.apply(img_l)
        img_lab = cv2.merge((img_l, img_a, img_b))
        img = cv2.cvtColor(img_lab, cv2.COLOR_LAB2RGB)

        # Save the preprocessed image to the output directory
        if label:
            output_dir_label = os.path.join(output_dir, str(label))
        else:
            output_dir_label = output_dir
        if not os.path.exists(output_dir_label):
            os.makedirs(output_dir_label)
        img_output_path = os.path.join(output_dir_label, f"{img_file}.png")
        cv2.imwrite(img_output_path, img)

# Preprocess the train images
train_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/train.csv'
train_img_dir = 'C:/Users/aa2150_local/Downloads/dataset/train_images'
train_output_dir = 'C:/Users/aa2150_local/Downloads/dataset/train_preprocessed'
preprocess_images(train_csv_file, train_img_dir, train_output_dir)

# Preprocess the test images
test_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/test.csv'
test_img_dir = 'C:/Users/aa2150_local/Downloads/dataset/test_images'
test_output_dir = 'C:/Users/aa2150_local/Downloads/dataset/test_preprocessed'
preprocess_images(test_csv_file, test_img_dir, test_output_dir)
# Out:
# 100%|██████████| 3662/3662 [04:52<00:00, 12.53it/s]
#  14%|█▍        | 269/1928 [00:12<01:21, 20.38it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png
#  19%|█▊        | 360/1928 [00:16<00:48, 32.65it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png
#  32%|███▏      | 610/1928 [00:26<00:41, 31.91it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png
#  39%|███▉      | 751/1928 [00:32<00:49, 23.63it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png
#  49%|████▉     | 953/1928 [00:40<00:25, 38.62it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png
# 100%|██████████| 1928/1928 [01:20<00:00, 23.98it/s]

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\aa2150_local\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.41.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.15.0)
# Requirement already satisfied: packaging in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (20.9)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.36.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aa2150_local\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aa2150_local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\aa2150_local\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aa2150_local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aa2150_local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aa2150_local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\aa2150_local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aa2150_local\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\aa2150_local\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import cv2
from keras.utils import to_categorical
import glob
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Set the paths for the train and test datasets
train_dir = 'C:/Users/aa2150_local/Downloads/dataset/train_preprocessed'
test_dir = 'C:/Users/aa2150_local/Downloads/dataset/test_preprocessed'
train_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/train.csv'
test_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/test.csv'

# %%
# Define the hyperparameters for the model
input_shape = (224, 224, 3)
num_classes = 5
batch_size = 32
num_epochs = 10
lr = 0.001


# Define the Capsule Network model
def CapsuleNetwork(input_shape, num_classes):
    # Input layer
    inputs = layers.Input(shape=input_shape)

    # Convolutional layers
    conv1 = layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')(inputs)
    conv2 = layers.Conv2D(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(conv1)
    conv3 = layers.Conv2D(filters=256, kernel_size=3, strides=1, padding='same', activation='relu')(conv2)

    # Primary Capsule layer
    primary_caps = layers.Conv2D(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(conv3)
    primary_caps = layers.Reshape(target_shape=(-1, 8))(primary_caps)

    # Digit Capsule layer
    digit_caps = layers.Dense(units=num_classes*16, activation='relu')(primary_caps)
    digit_caps = layers.Reshape(target_shape=(-1, num_classes, 16))(digit_caps)
    digit_caps = layers.Lambda(lambda x: x / tf.norm(x, axis=-1, keepdims=True))(digit_caps)

    # Output layer
    outputs = layers.Flatten()(digit_caps)
    model = models.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
preprocess_images(train_csv_file, train_img_dir, train_output_dir)
preprocess_images(test_csv_file, test_img_dir, test_output_dir)
# Out:
# 100%|██████████| 3662/3662 [04:42<00:00, 12.95it/s]
#  14%|█▍        | 272/1928 [00:09<01:09, 23.89it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png
#  19%|█▊        | 357/1928 [00:12<00:43, 36.25it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png
#  32%|███▏      | 612/1928 [00:20<00:36, 36.45it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png
#  39%|███▉      | 751/1928 [00:25<00:33, 35.47it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png
#  49%|████▉     | 951/1928 [00:32<00:20, 48.32it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png
# 100%|██████████| 1928/1928 [01:07<00:00, 28.57it/s]

# %%
# Preprocess the train and test images
preprocess_images(train_csv_file, train_img_dir, train_output_dir)
preprocess_images(test_csv_file, test_img_dir, test_output_dir)
# Load the train and test datasets
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=input_shape[:2],
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=input_shape[:2],
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Define the model and compile it
model = CapsuleNetwork(input_shape, num_classes)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(lr=lr),
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=len(train_generator),
                    epochs=num_epochs,
                    validation_data=test_generator,
                    validation_steps=len(test_generator))

# Save the trained model
model.save('capsule_network_model.h5')

# Evaluate the model
test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# 100%|██████████| 3662/3662 [04:22<00:00, 13.93it/s]
#  14%|█▍        | 272/1928 [00:10<01:13, 22.45it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png
#  19%|█▊        | 357/1928 [00:13<00:40, 38.46it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png
#  32%|███▏      | 612/1928 [00:22<00:46, 28.38it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png
#  39%|███▉      | 754/1928 [00:27<00:38, 30.85it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png
#  49%|████▉     | 951/1928 [00:34<00:20, 46.66it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png
# 100%|██████████| 1928/1928 [01:11<00:00, 27.00it/s]
# Found 1857 images belonging to 4 classes.
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd9fa1403b7d> in <module>
#      15
#      16 # Define the model and compile it
# ---> 17 model = CapsuleNetwork(input_shape, num_classes)
#      18 model.compile(loss='categorical_crossentropy',
#      19               optimizer=optimizers.Adam(lr=lr),
#
# <ipython-input-5-c08f3ca8fc33> in CapsuleNetwork(input_shape, num_classes)
#      24     digit_caps = layers.Dense(units=num_classes*16, activation='relu')(primary_caps)
#      25     digit_caps = layers.Reshape(target_shape=(-1, num_classes, 16))(digit_caps)
# ---> 26     digit_caps = layers.Lambda(lambda x: x / tf.norm(x, axis=-1, keepdims=True))(digit_caps)
#      27
#      28     # Output layer
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-5-c08f3ca8fc33> in <lambda>(x)
#      24     digit_caps = layers.Dense(units=num_classes*16, activation='relu')(primary_caps)
#      25     digit_caps = layers.Reshape(target_shape=(-1, num_classes, 16))(digit_caps)
# ---> 26     digit_caps = layers.Lambda(lambda x: x / tf.norm(x, axis=-1, keepdims=True))(digit_caps)
#      27
#      28     # Output layer
#
# NameError: Exception encountered when calling layer "lambda" (type Lambda).
#
# name 'tf' is not defined
#
# Call arguments received by layer "lambda" (type Lambda):
#   • inputs=tf.Tensor(shape=(None, 100352, 5, 16), dtype=float32)
#   • mask=None
#   • training=None

# %%
import os
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf  # import TensorFlow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

# %%
# Set the paths for the train and test datasets
train_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/train.csv'
train_img_dir = 'C:/Users/aa2150_local/Downloads/dataset/train_images'
train_output_dir = 'C:/Users/aa2150_local/Downloads/dataset/train_preprocessed'
# Preprocess the test images
test_csv_file = 'C:/Users/aa2150_local/Downloads/dataset/test.csv'
test_img_dir = 'C:/Users/aa2150_local/Downloads/dataset/test_images'
test_output_dir = 'C:/Users/aa2150_local/Downloads/dataset/test_preprocessed'

# %%
# Function to preprocess the images
def preprocess_images(csv_file, img_dir, output_dir):
    # Read the CSV file
    df = pd.read_csv(csv_file)

    # Loop through each row in the CSV file
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # Get the image file name and label
        img_file = row['id_code']
        label = None
        if 'diagnosis' in row:
            label = row['diagnosis']
        # Load the image and resize
        img_path = os.path.join(img_dir, f"{img_file}.png")
        try:
            img = cv2.imread(img_path)
            if img is None:
                raise ValueError(f"Failed to load image at path {img_path}")
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (512, 512))
        except Exception as e:
            print(f"Error preprocessing image {img_path}: {e}")
            continue

        # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
        img_lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        img_l, img_a, img_b = cv2.split(img_lab)
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        img_l = clahe.apply(img_l)
        img_lab = cv2.merge((img_l, img_a, img_b))
        img = cv2.cvtColor(img_lab, cv2.COLOR_LAB2RGB)

        # Save the preprocessed image to the output directory
        if label:
            output_dir_label = os.path.join(output_dir, str(label))
        else:
            output_dir_label = output_dir
        if not os.path.exists(output_dir_label):
            os.makedirs(output_dir_label)
        img_output_path = os.path.join(output_dir_label, f"{img_file}.png")
        cv2.imwrite(img_output_path, img)

# %%
# Preprocess the train and test images
preprocess_images(train_csv_file, train_img_dir, train_output_dir)
preprocess_images(test_csv_file, test_img_dir, test_output_dir)
# Out:
# 100%|██████████| 3662/3662 [04:29<00:00, 13.57it/s]
#  14%|█▍        | 272/1928 [00:09<01:11, 23.15it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\2.87613E+11.png
#  19%|█▊        | 357/1928 [00:12<00:37, 42.44it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\3.26808E+11.png
#  32%|███▏      | 613/1928 [00:20<00:37, 35.49it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\5.32E+81.png
#  39%|███▉      | 750/1928 [00:25<00:36, 32.58it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\6.62786E+11.png
#  49%|████▉     | 954/1928 [00:32<00:21, 45.81it/s]
# Error preprocessing image C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png: Failed to load image at path C:/Users/aa2150_local/Downloads/dataset/test_images\8.31826E+11.png
# 100%|██████████| 1928/1928 [01:10<00:00, 27.39it/s]

# %%
# Define the hyperparameters for the model
input_shape = (224, 224, 3)
num_classes = 5
batch_size = 32
num_epochs = 10
lr = 0.001

# %%
# Load the train and test datasets
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_output_dir,
                                                    target_size=input_shape[:2],
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_output_dir,
                                                  target_size=input_shape[:2],
                                                  batch_size=batch_size,
                                                  class_mode='categorical')
# Out:
# Found 1857 images belonging to 4 classes.
# Found 0 images belonging to 0 classes.

# %%
test_filepaths = test_generator.filepaths
print(test_filepaths)
# Out:
# []

# %%
# Check the number of samples in the train and test sets
num_train_samples = len(train_generator.filenames)
num_test_samples = len(test_generator.filenames)
print(f"Number of samples in the train set: {num_train_samples}")
print(f"Number of samples in the test set: {num_test_samples}")
# Out:
# Number of samples in the train set: 1857
# Number of samples in the test set: 0

# %%
# One-hot encode the labels
train_labels = to_categorical(train_generator.classes)
test_labels = to_categorical(test_generator.classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-20389b99d00f> in <module>
#       1 # One-hot encode the labels
#       2 train_labels = to_categorical(train_generator.classes)
# ----> 3 test_labels = to_categorical(test_generator.classes)
#       4
#
# ~\anaconda3\lib\site-packages\keras\utils\np_utils.py in to_categorical(y, num_classes, dtype)
#      68     y = y.ravel()
#      69     if not num_classes:
# ---> 70         num_classes = np.max(y) + 1
#      71     n = y.shape[0]
#      72     categorical = np.zeros((n, num_classes), dtype=dtype)
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import os

for root, dirs, files in os.walk(test_output_dir):
    for file in files:
        print(os.path.join(root, file))
# Out:
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0005cfc8afb6.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\003f0afdcd15.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\006efc72b638.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\00836aaacf06.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\009245722fa4.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\009c019a7309.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\010d915e229a.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0111b949947e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\01499815e469.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0167076e7089.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\01c31b10ab99.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\01c5ba195207.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\01e4d86b3a30.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\020921b796d5.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\020f6983114d.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\021c207614d6.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0229c0a80d42.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\024d0a225db1.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0268f4382c67.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\0299d97f31f7.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed
.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f9642cf6a5bb.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f96f06803471.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f96fecb16957.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f99a9ad63dda.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f9e7f614c91d.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f9f1cd9ed16c.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\f9f3d97f3269.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa007743976a.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa09c97a2887.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa7a97f4de76.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa8b04533b99.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa98490bc13c.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fa988ad2271e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fab7d8e8a1fa.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fac5beea82bd.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fb2d29623cfc.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fb5b3c8d9cbb.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fb75ed010413.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fbb5cb3a2222.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fbc502a64901.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fbc8b60526f1.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fbcd28a51ef7.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fbe36fdd76be.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc3935afc788.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc44a4ffaa45.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc5ea7f74c48.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc66648f758e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc67df1e574e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc6c9d0efe53.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fc79feb5deed.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fcbc1f4b5342.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fcd166e6e4b5.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fcea00df9f33.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fd2978398705.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fd2d58c6cd45.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fd4d81b43e84.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fd7cc592106e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fd8e6b0b2e45.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fda8612fcc8c.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fdde61dd1bde.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fde8778182af.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe0a340c4477.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe190d618acf.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe1d2f703efc.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe5618ad2460.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe57ff56618e.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe84ad1df04b.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fe920e47b72d.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fed9d587f158.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fee5bd042c3b.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\fef8e645d030.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\ff2fd94448de.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\ff4c945d9b17.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\ff64897ac0d8.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\ffa73465b705.png
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed\ffdc2152d455.png

# %%
print(test_generator.directory)
# Out:
# C:/Users/aa2150_local/Downloads/dataset/test_preprocessed

# %%
# One-hot encode the labels
train_labels = to_categorical(train_generator.classes)
test_labels = to_categorical(test_generator.classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2aa50f7f905a> in <module>
#       1 # One-hot encode the labels
#       2 train_labels = to_categorical(train_generator.classes)
# ----> 3 test_labels = to_categorical(test_generator.classes)
#
# ~\anaconda3\lib\site-packages\keras\utils\np_utils.py in to_categorical(y, num_classes, dtype)
#      68     y = y.ravel()
#      69     if not num_classes:
# ---> 70         num_classes = np.max(y) + 1
#      71     n = y.shape[0]
#      72     categorical = np.zeros((n, num_classes), dtype=dtype)
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# Define the Capsule Network model
def CapsuleNetwork(input_shape, num_classes):
    # Input layer
    inputs = layers.Input(shape=input_shape)

    # Convolutional layers
    conv1 = layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')(inputs)
    conv2 = layers.Conv2D(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(conv1)
    conv3 = layers.Conv2D(filters=256, kernel_size=3, strides=1, padding='same', activation='relu')(conv2)

    # Primary Capsule layer
    primary_caps = layers.Conv2D(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(conv3)
    primary_caps = layers.Reshape(target_shape=(-1, 8))(primary_caps)

    # Digit Capsule layer
    digit_caps = layers.Dense(units=num_classes*16, activation='relu')(primary_caps)
    digit_caps = layers.Reshape(target_shape=(-1, num_classes, 16))(digit_caps)
    digit_caps = layers.Lambda(lambda x: x / tf.norm(x, axis=-1, keepdims=True))(digit_caps)

    # Output layer
    outputs = layers.Flatten()(digit_caps)
    model = models.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
# Define the model and compile it
model = CapsuleNetwork(input_shape, num_classes)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(learning_rate=lr),
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=len(train_generator),
                    epochs=num_epochs,
                    validation_data=test_generator,
                    validation_steps=len(test_generator))
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-29-5a124052f307> in <module>
#       1 # Train the model
# ----> 2 history = model.fit(train_generator,
#       3                     steps_per_epoch=len(train_generator),
#       4                     epochs=num_epochs,
#       5                     validation_data=test_generator,
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/categorical_crossentropy/mul/BroadcastGradientArgs' defined at (most recent call last):
#     File "C:\Users\aa2150_local\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\aa2150_local\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#       app.start()
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#       self.io_loop.start()
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\aa2150_local\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "C:\Users\aa2150_local\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "C:\Users\aa2150_local\anaconda3\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#       ret = callback()
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#       self.ctx_run(self.run)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#       yielded = self.gen.send(value)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#       self.do_execute(
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#       result = self._run_cell(
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-29-5a124052f307>", line 2, in <module>
#       history = model.fit(train_generator,
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\engine\training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\engine\training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\engine\training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\engine\training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py", line 526, in minimize
#       grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     File "C:\Users\aa2150_local\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py", line 259, in compute_gradients
#       grads = tape.gradient(loss, var_list)
# Node: 'gradient_tape/categorical_crossentropy/mul/BroadcastGradientArgs'
# Incompatible shapes: [32,4] vs. [32,8028160]
# 	 [[{{node gradient_tape/categorical_crossentropy/mul/BroadcastGradientArgs}}]] [Op:__inference_train_function_1885]

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f0178070f4c9> in <module>
#       1 # Plot the training and validation accuracy
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('Model Accuracy')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-45aa35b69916> in <module>
#       1 # Plot the training and validation loss
# ----> 2 plt.plot(history.history['loss'])
#       3 plt.plot(history.history['val_loss'])
#       4 plt.title('Model Loss')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
# Save the trained model
model.save('capsule_network_model.h5')

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2e2637bad270> in <module>
#       1 # Evaluate the model
# ----> 2 test_loss, test_acc = model.evaluate(test_generator, verbose=2)
#       3 print('Test accuracy:', test_acc)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\preprocessing\image.py in __getitem__(self, idx)
#     101     def __getitem__(self, idx):
#     102         if idx >= len(self):
# --> 103             raise ValueError(
#     104                 "Asked to retrieve element {idx}, "
#     105                 "but the Sequence "
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %%
# Get a batch of images from the test generator
images, labels = next(test_generator)

# Plot the images
fig, axs = plt.subplots(4, 4, figsize=(10, 10))
axs = axs.ravel()
for i in range(16):
    axs[i].imshow(images[i])
    axs[i].set_title('Label: {}'.format(labels[i]))
    axs[i].axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-21579984440d> in <module>
#       6 axs = axs.ravel()
#       7 for i in range(16):
# ----> 8     axs[i].imshow(images[i])
#       9     axs[i].set_title('Label: {}'.format(labels[i]))
#      10     axs[i].axis('off')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
